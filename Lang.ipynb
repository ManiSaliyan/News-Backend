# %%
# !pip install transformers -U -q

# %%
! pip install sentencepiece

# %%
# !pip freeze | grep transformers
# Out:
# sentence-transformers==3.4.1
# transformers==4.51.3

# %%
from transformers import MBartForConditionalGeneration, MBart50TokenizerFast

# %%
model = MBartForConditionalGeneration.from_pretrained("facebook/mbart-large-50-one-to-many-mmt")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.43k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/2.44G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.44G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/261 [00:00<?, ?B/s]

# %%
tokenizer = MBart50TokenizerFast.from_pretrained("facebook/mbart-large-50-one-to-many-mmt", src_lang="en_XX")
# Out:
# tokenizer_config.json:   0%|          | 0.00/528 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/717 [00:00<?, ?B/s]

# %%
article_en = "U.N encourages wearing masks"

# %%
model_inputs = tokenizer(article_en, return_tensors="pt")

# %%
generated_tokens = model.generate(
    **model_inputs,
    forced_bos_token_id=tokenizer.lang_code_to_id["hi_IN"]
)

# %%
translation = tokenizer.batch_decode(generated_tokens, skip_special_tokens=True)

# %%
translation
# Out:
# ['संयुक्त राष्ट्र द्वारा मास्क पहनने को प्रोत्साहित']

# %%
#!pip install transformers -U -q
#! pip install sentencepiece
#! pip install sentencepiece

from transformers import MBartForConditionalGeneration, MBart50TokenizerFast

model = MBartForConditionalGeneration.from_pretrained("facebook/mbart-large-50-one-to-many-mmt")
tokenizer = MBart50TokenizerFast.from_pretrained("facebook/mbart-large-50-one-to-many-mmt", src_lang="en_XX")
print(tokenizer.lang_code_to_id.keys())
def indianTrans(text,lang):
    model_inputs = tokenizer(text, return_tensors="pt")
    generated_tokens = model.generate(
    **model_inputs,
    forced_bos_token_id=tokenizer.lang_code_to_id[lang])
    translation = tokenizer.batch_decode(generated_tokens, skip_special_tokens=True)
    return translation

res = indianTrans("My name is Manikantan","ml_IN")
print(res)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-612de09ec352> in <cell line: 0>()
#       6
#       7 model = MBartForConditionalGeneration.from_pretrained("facebook/mbart-large-50-one-to-many-mmt")
# ----> 8 tokenizer = MBart50TokenizerFast.from_pretrained("facebook/mbart-large-50-one-to-many-mmt", src_lang="en_XX")
#       9 print(tokenizer.lang_code_to_token.keys())
#      10 def indianTrans(text,lang):
#
# /usr/local/lib/python3.11/dist-packages/transformers/tokenization_utils_base.py in from_pretrained(cls, pretrained_model_name_or_path, cache_dir, force_download, local_files_only, token, revision, trust_remote_code, *init_inputs, **kwargs)
#    2060                 logger.info(f"loading file {file_path} from cache at {resolved_vocab_files[file_id]}")
#    2061
# -> 2062         return cls._from_pretrained(
#    2063             resolved_vocab_files,
# ...

# %%
#!pip install transformers -U -q
#! pip install sentencepiece
#! pip install sentencepiece

from transformers import AutoModelForSeq2SeqLM, AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("facebook/nllb-200-distilled-600M")
#print(tokenizer.lang_code_to_id.keys())
model = AutoModelForSeq2SeqLM.from_pretrained("facebook/nllb-200-distilled-600M")

text = "UN Chief says there is no military solution in Syria"
def indianTrans(text,lang):
    inputs = tokenizer(text, return_tensors="pt")
    translated_tokens = model.generate(**inputs, forced_bos_token_id=tokenizer.convert_tokens_to_ids(lang))
    t=tokenizer.batch_decode(translated_tokens, skip_special_tokens=True)[0]
    return t

res = indianTrans("Hey Tech Enthusiasts!Get ready to code, compete, and conquer at our biggest tech showdown of the year — InnoV8rix & HackSummit '25 are here!From mind-bending tech challenges to a thrilling 24-hour hackathon, this is your chance to innovate, collaborate, and shine. Whether you're into coding, design, or just passionate about tech — there’s something for everyone.This is an intercollegiate event, open to students from both professional and non-professional courses. So no matter your background, if you’ve got the passion — you’re welcome to join the fun!Venue: P A College of EngineeringDates: May 12 – May 16Brochure drops today! Want to know more?Scan the QR code to explore event details, rules, and registration info.Click here to visit our website:https://glugpace.org/events/innov8rix-x-hacksummit25/Let’s make this the tech fest to remember!#InnoV8rix #HackSummit25 #TechUnleashed #CodeCollaborateConquer","kan_Knda")
print(res)
# Out:
# ಹೈ ಟೆಕ್ ಉತ್ಸಾಹಿಗಳು!ಈ ವರ್ಷದ ನಮ್ಮ ಅತಿದೊಡ್ಡ ತಂತ್ರಜ್ಞಾನ ಪ್ರದರ್ಶನದಲ್ಲಿ ಕೋಡ್ ಮಾಡಲು, ಸ್ಪರ್ಧಿಸಲು ಮತ್ತು ಗೆಲ್ಲಲು ಸಿದ್ಧರಾಗಿರಿ  InnoV8rix & HackSummit '25 ಇಲ್ಲಿದೆ!ಮನಸ್ಸನ್ನು ತಿರುಗಿಸುವ ತಂತ್ರಜ್ಞಾನ ಸವಾಲುಗಳಿಂದ 24 ಗಂಟೆಗಳ ರೋಮಾಂಚಕಾರಿ ಹ್ಯಾಕಥಾನ್ವರೆಗೆ, ಇದು ನಿಮ್ಮ ನಾವೀನ್ಯತೆ, ಸಹಯೋಗ ಮತ್ತು ಹೊಳಪಿನ ಅವಕಾಶವಾಗಿದೆ. ನೀವು ಕೋಡಿಂಗ್, ವಿನ್ಯಾಸ ಅಥವಾ ತಂತ್ರಜ್ಞಾನದ ಬಗ್ಗೆ ಉತ್ಸುಕರಾಗಿದ್ದರೆ  ಎಲ್ಲರಿಗೂ ಏನಾದರೂ ಇದೆ. ಇದು ವೃತ್ತಿಪರ ಮತ್ತು ವೃತ್ತಿಪರವಲ್ಲದ ಕೋರ್ಸ್ಗಳ ವಿದ್ಯಾರ್ಥಿಗಳಿಗೆ ಮುಕ್ತವಾದ ಅಂತರ ಕಾಲೇಜು ಕಾರ್ಯಕ್ರಮವಾಗಿದೆ. ಆದ್ದರಿಂದ ನಿಮ್ಮ ಹಿನ್ನೆಲೆ  ನೀವು  ಉತ್ಸುಕರಾಗಿದ್ದರೆ  ನೀವು  ವಿನೋದಕ್ಕೆ ಸೇರಲು ಸ್ವಾಗತ!ವೀನ್ಯತೆಃ ಪಿ ಎ ಕಾಲೇಜ್ ಆಫ್ ಎಂಜಿನಿಯರಿಂಗ್ ದಿನಾಂಕಗಳುಃ ಮೇ 12  ಮೇ 16Bashure  ನೀವು ಇನ್ನಷ್ಟು ತಿಳಿದುಕೊಳ್ಳಲು ಬಯಸುತ್ತೀರಿ!ಈ

# %%
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("facebook/nllb-200-distilled-600M")
model = AutoModelForSeq2SeqLM.from_pretrained("facebook/nllb-200-distilled-600M")

#translation function
def indianTrans(text,lang):
    inputs = tokenizer(text, return_tensors="pt")
    translated_tokens = model.generate(**inputs, forced_bos_token_id=tokenizer.convert_tokens_to_ids(lang))
    t=tokenizer.batch_decode(translated_tokens, skip_special_tokens=True)[0]
    return t


data = {"post_id": "1","img_url":"https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/09_sep/21_tue/img_1632243978497_14.jpg?","title":"Now achieve your biggest career goals: Simplilearn","short_des":"Over the past 18 months, professionals worldwide achieved phenomenal salary hikes, promotions & career changes with Simplilearn, the online learning platform revealed.","desc":"Over the past 18 months, professionals worldwide achieved phenomenal salary hikes, promotions & career changes with Simplilearn, the online learning platform revealed. It offers Bootcamp programs in partnership with top universities and firms and has helped millions of learners upskill in Data & AI, Full Stack Development, Digital Marketing, MBA, other digital economy job areas, Simplilearn added.","author":"Roshan Gupta","created_at":"22 Sep"}
item = {"postID": data["post_id"],
        "img": data["img_url"],
        "Title": data["title"],
        "ShDes": data["short_des"],
        "Descripton": data["desc"],
        "Author": data["author"],
        "Created_at": data["created_at"]
       }
#Tamil
tamilTitle = indianTrans(data["title"],"tam_Taml")
tamilShortDes = indianTrans(data["short_des"],"tam_Taml")
tamilDes = indianTrans(data["desc"],"tam_Taml")
tamilAuthor = indianTrans(data["author"],"tam_Taml")
#kanada
kannadaTitle = indianTrans(data["title"],"kan_Knda")
kannadaShortDes = indianTrans(data["short_des"],"kan_Knda")
kannadaDes = indianTrans(data["desc"],"kan_Knda")
kannadaAuthor = indianTrans(data["author"],"kan_Knda")
#malayalam
malayalamTitle = indianTrans(data["title"],"mal_Mlym")
malayalamShortDes = indianTrans(data["short_des"],"mal_Mlym")
malayalamDes = indianTrans(data["desc"],"mal_Mlym")
malayalamAuthor = indianTrans(data["author"],"mal_Mlym")
tamilItem = {"postID": data["post_id"],
        "img": data["img_url"],
        "Title": tamilTitle,
        "ShDes": tamilShortDes,
        "Descripton": tamilDes,
        "Author": tamilAuthor,
        "Created_at": data["created_at"]
       }
kannadaItem = {"postID": data["post_id"],
        "img": data["img_url"],
        "Title": kannadaTitle,
        "ShDes": kannadaShortDes,
        "Descripton": kannadaDes,
        "Author": kannadaAuthor,
        "Created_at": data["created_at"]
       }
malayalamItem = {"postID": data["post_id"],
        "img": data["img_url"],
        "Title": malayalamTitle,
        "ShDes": malayalamShortDes,
        "Descripton": malayalamDes,
        "Author": malayalamAuthor,
        "Created_at": data["created_at"]
       }

print(tamilItem)
print("\n")
print(kannadaItem)
print("\n")
print(malayalamItem)
    # tamil.insert_one(tamilItem)
    # malayalam.insert_one(malayalamItem)
    # kannada.insert_one(kannadaItem)


    # result = english.insert_one(item)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/564 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/4.85M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.3M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/3.55k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/846 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/2.46G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.46G [00:00<?, ?B/s]
# ...

# %%
# !pip install pymongo
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 19.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 21.2 MB/s eta 0:00:00
# ...

# %%
from pymongo import MongoClient
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer

# Connect to MongoDB
client = MongoClient("mongodb+srv://manisalian:PqXNq8KvMLpXplxP@crud.jeyup.mongodb.net/Love?retryWrites=true&w=majority&appName=CRUD")
db = client["CRUD"]  # Replace with your DB name

tokenizer = AutoTokenizer.from_pretrained("facebook/nllb-200-distilled-600M")
model = AutoModelForSeq2SeqLM.from_pretrained("facebook/nllb-200-distilled-600M")

# 38 language codes and names (arrays should match index-wise)
language_codes = ["hin_Deva", "awa_Deva", "bho_Deva", "bra_Deva", "mag_Deva", "mai_Deva","urd_Arab", "ben_Beng", "sat_Olck", "ori_Orya", "unr_Latn", "hoc_Wara","kjh_Deva", "hne_Deva", "bgw_Deva", "mup_Deva", "bns_Deva", "kan_Knda","tel_Telu", "tam_Taml", "mal_Mlym", "tcy_Knda", "guj_Gujr", "mar_Deva","gom_Deva", "raj_Deva", "mwr_Deva", "asm_Beng", "brx_Deva", "mni_Beng","kha_Latn", "grt_Latn", "lus_Latn", "kru_Deva", "sck_Deva", "ggo_Deva","bhb_Deva", "lmn_Telu"] # Your list from earlier
language_names =  ["Hindi", "Awadhi", "Bhojpuri", "Braj", "Magahi", "Maithili","Urdu", "Bengali", "Santali", "Odia (Oriya)", "Mundari", "Ho","Kharia", "Chhattisgarhi", "Bagheli", "Malvi", "Bundeli", "Kannada","Telugu", "Tamil", "Malayalam", "Tulu", "Gujarati", "Marathi","Konkani", "Rajasthani", "Marwari", "Assamese", "Bodo", "Meitei (Manipuri)","Khasi", "Garo", "Mizo", "Kurukh (Oraon)", "Sadri", "Gond","Bhili", "Lambadi"] # Your list from earlier

#translation function
def indianTrans(text,lang):
    inputs = tokenizer(text, return_tensors="pt")
    translated_tokens = model.generate(**inputs, forced_bos_token_id=tokenizer.convert_tokens_to_ids(lang))
    t=tokenizer.batch_decode(translated_tokens, skip_special_tokens=True)[0]
    return t


# English input (to be translated)
english_data = {
    "title": "Understanding Digital Payments",
    "author": "John Doe",
    "short_desc": "A short guide to digital financial transactions.",
    "desc": "This article explains how digital payments work and how to use UPI, wallets, and bank apps safely."
}

# Loop over languages and insert translated data
for code, name in zip(language_codes, language_names):
    translated_data = {
        "title": indianTrans(english_data["title"], code),
        "author": indianTrans(english_data["author"], code),
        "short_desc": indianTrans(english_data["short_desc"], code),
        "desc": indianTrans(english_data["desc"], code)
    }

    # Insert into respective collection
    collection = db[name]  # Make sure your MongoDB collection names match language_names exactly
    collection.insert_one(translated_data)

    print(f"Inserted into {name} collection.")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/564 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/4.85M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.3M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/3.55k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/846 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/2.46G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.46G [00:00<?, ?B/s]
# ...

# %%
from pymongo import MongoClient
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer
from datetime import datetime

# Connect to MongoDB
client = MongoClient("mongodb+srv://manisalian:PqXNq8KvMLpXplxP@crud.jeyup.mongodb.net/NEWS?retryWrites=true&w=majority&appName=NEWS")
db = client["NEWS"]  # Replace with your DB name
colection = db["Assamese"]
count = colection.count_documents({})
tokenizer = AutoTokenizer.from_pretrained("facebook/nllb-200-distilled-600M")
model = AutoModelForSeq2SeqLM.from_pretrained("facebook/nllb-200-distilled-600M")

# 38 language codes and names (arrays should match index-wise)
language_codes = ["asm_Beng","awa_Deva","ben_Beng","bho_Deva","hne_Deva","guj_Gujr","hin_Deva","kan_Knda","mag_Deva","mai_Deva","mal_Mlym","mar_Deva","mni_Beng","lus_Latn","tam_Taml","tel_Telu","urd_Arab"]
language_names =  ["Assamese", "Awadhi", "Bengali", "Bhojpuri", "Chhattisgarhi","Gujarati", "Hindi", "Kannada", "Magahi", "Maithili","Malayalam", "Marathi", "Meithei", "Mizo", "Tamil","Telugu", "Urdu"]

#translation function
def indianTrans(text,lang):
    inputs = tokenizer(text, return_tensors="pt")
    translated_tokens = model.generate(**inputs, forced_bos_token_id=tokenizer.convert_tokens_to_ids(lang))
    t=tokenizer.batch_decode(translated_tokens, skip_special_tokens=True)[0]
    return t


# English input (to be translated)
english_data = {
    "post_id":count+1,
    "img_url": "https://m.economictimes.com/thumb/height-450,width-600,imgsize-12238,msid-121144263/rbi-caps-fema-violation-penalty-at-2-lakh-to-ease-compliance-burden.jpg",
    "title": "Currency in circulation grows 2.4% on year till May 2, shows RBI data",
    "author": "John Doe",
    "short_desc": "A short guide to digital financial transactions.",
    "desc": "Growth in currency in circulation is higher at 2.4% year to date up to May 2, compared with 1.7 percent in the same period a year ago, showed the latest Reserve Bank of India (RBI) data, reflecting rural demand supported by farmgate prices of agricultural commodities.  Currency usage has remained relatively strong despite the absence of a busy election calendar during which cash usage typically climbs.  Total currency in circulation is at Rs 38.1 lakh crore as of May 2. This works to around 11.5 percent of GDP, and is at half a percentage point less than the levels that were prevailing at the time of demonetisation of Rs 500 and Rs 1000 notes in November 2016.  There is an inverse relation between currency in circulation and rupee liquidity in the system. Hence, a rise in currency in circulation results in a reduction of system level liquidity and vice-versa. Hence, most treasury economists refer to increase in currency in circulation as leakage from the system. Economists attribute this trend to higher farm output that triggered a rise in rural demand.  The pickup in currency in circulation started from the end of FY '25, said Gaura Sengupta, chief economist, IDFC First Bank. “This is likely led by a recovery in rural demand supported by strong rabi and kharif output. In FY26, we expect full-year currency leakage to be marginally higher at Rs 2.2 lakh crore.  This leakage was Rs 2.09 lakh crore in FY25.  Cash usage suggests currency notes are still a major driver of consumption expenditure. As the share of digital payments keeps increasing, cash continues to account for a majority share of consumer expenditure at 60%, as of March 2024, said a recent report by cash logistics company CMS Info Systems released last week.  Between 2014 and 2024, several enablers have aligned to propel the cash economy, which, in turn, has been instrumental in the making of a consumption economy. In this period, Currency in Circulation (CIC) more than doubled, the number of ATMs climbed 32%, and the number of bank branches expanded 36%, central bank data showed While India has been successful in managing the tenuous balance between cash and digital by simultaneously building infrastructure for both, cash consumption continues to dominate India’s consumption story, CMS said",
    "created_on": datetime.now()
}

# Loop over languages and insert translated data
for code, name in zip(language_codes, language_names):
    translated_data = {
        "post_id": english_data["post_id"],
        "img_url": english_data["img_url"],
        "title": indianTrans(english_data["title"], code),
        "author": indianTrans(english_data["author"], code),
        "short_desc": indianTrans(english_data["short_desc"], code),
        "desc": indianTrans(english_data["desc"], code),
        "created_on": english_data["created_on"]
    }

    # Insert into respective collection
    collection = db[name]  # Make sure your MongoDB collection names match language_names exactly
    collection.insert_one(translated_data)

    print(f"Inserted into {name} collection.")
collection = db["English"]  # Make sure your MongoDB collection names match language_names exactly
collection.insert_one(english_data)
print("Inserted into English collection.")
# Out:
# Inserted into Assamese collection.
# Inserted into Awadhi collection.
# Inserted into Bengali collection.
# Inserted into Bhojpuri collection.
# Inserted into Chhattisgarhi collection.
# Inserted into Gujarati collection.
# Inserted into Hindi collection.
# Inserted into Kannada collection.
# Inserted into Magahi collection.
# Inserted into Maithili collection.
# Inserted into Malayalam collection.
# Inserted into Marathi collection.
# Inserted into Meithei collection.
# Inserted into Mizo collection.
# Inserted into Tamil collection.
# Inserted into Telugu collection.
# Inserted into Urdu collection.
# Inserted into English collection.

# %%
from pymongo import MongoClient
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer
from datetime import datetime

# Connect to MongoDB
client = MongoClient("mongodb+srv://manisalian:PqXNq8KvMLpXplxP@crud.jeyup.mongodb.net/finQuiz?retryWrites=true&w=majority&appName=finQuiz")
db = client["finQuiz"]  # Replace with your DB name
colection = db["Assamese"]
count = colection.count_documents({})
tokenizer = AutoTokenizer.from_pretrained("facebook/nllb-200-distilled-600M")
model = AutoModelForSeq2SeqLM.from_pretrained("facebook/nllb-200-distilled-600M")

# 38 language codes and names (arrays should match index-wise)
language_codes = ["asm_Beng","awa_Deva","ben_Beng","bho_Deva","hne_Deva","guj_Gujr","hin_Deva","kan_Knda","mag_Deva","mai_Deva","mal_Mlym","mar_Deva","mni_Beng","lus_Latn","tam_Taml","tel_Telu","urd_Arab"]
language_names =  ["Assamese", "Awadhi", "Bengali", "Bhojpuri", "Chhattisgarhi","Gujarati", "Hindi", "Kannada", "Magahi", "Maithili","Malayalam", "Marathi", "Meithei", "Mizo", "Tamil","Telugu", "Urdu"]

#translation function
def indianTrans(text,lang):
    inputs = tokenizer(text, return_tensors="pt")
    translated_tokens = model.generate(**inputs, forced_bos_token_id=tokenizer.convert_tokens_to_ids(lang))
    t=tokenizer.batch_decode(translated_tokens, skip_special_tokens=True)[0]
    return t

# Function to translate and store array of texts
def translate_array_and_store(text_array, lang_code, lang_name):
    translated_array = [indianTrans(text, lang_code) for text in text_array]
    translated_array_str = str(translated_array)  # Convert list to string

    # Prepare document
    array_doc = {
        "language": lang_name,
        "translated_array": translated_array_str,
        "created_on": datetime.now()
    }

    # Insert into a common collection or language-specific collection
    db["TranslatedArrays"].insert_one(array_doc)
    print(f"Translated array stored for {lang_name}")

# Example input array (you can replace this with your dynamic input)
input_texts = [ "What is the purpose of creating a budget?", "Define 'fixed expenses' and provide an example.", "What are 'variable expenses' and give an example.", "Explain the difference between needs and wants in budgeting.", "What is an emergency fund, and why is it important in budgeting?", "What is the 'zero-based budgeting' method?", "Define the term 'budget variance' in budgeting.", "What is the 'envelope system' of budgeting?", "What is the 50/30/20 rule in budgeting?", "Explain the concept of 'sinking funds' in budgeting.", "What is 'tracking expenses', and why is it essential in budgeting?", "Define the term 'financial goal' in budgeting.", "What are the benefits of budgeting?", "Explain the concept of 'rolling budget' in budgeting.", "How can budgeting help in reducing debt?" ]

# Loop through language codes and names to process all
for code, name in zip(language_codes, language_names):
    translate_array_and_store(input_texts, code, name)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-4bd704e1e6fc> in <cell line: 0>()
# ----> 1 from pymongo import MongoClient
#       2 from transformers import AutoModelForSeq2SeqLM, AutoTokenizer
#       3 from datetime import datetime
#       4
#       5 # Connect to MongoDB
#
# ModuleNotFoundError: No module named 'pymongo'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install pymongo
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 18.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 22.0 MB/s eta 0:00:00
# ...

# %%
from pymongo import MongoClient
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer
from datetime import datetime

# Connect to MongoDB
client = MongoClient("mongodb+srv://manisalian:PqXNq8KvMLpXplxP@crud.jeyup.mongodb.net/finQuiz?retryWrites=true&w=majority&appName=finQuiz")
db = client["finQuiz"]
tokenizer = AutoTokenizer.from_pretrained("facebook/nllb-200-distilled-600M")
model = AutoModelForSeq2SeqLM.from_pretrained("facebook/nllb-200-distilled-600M")

# Languages
language_codes = ["asm_Beng","awa_Deva","ben_Beng","bho_Deva","hne_Deva","guj_Gujr","hin_Deva","kan_Knda","mag_Deva","mai_Deva","mal_Mlym","mar_Deva","mni_Beng","lus_Latn","tam_Taml","tel_Telu","urd_Arab"]
language_names = ["Assamese", "Awadhi", "Bengali", "Bhojpuri", "Chhattisgarhi","Gujarati", "Hindi", "Kannada", "Magahi", "Maithili","Malayalam", "Marathi", "Meithei", "Mizo", "Tamil","Telugu", "Urdu"]

# Translation function
def indianTrans(text, lang_code):
    inputs = tokenizer(text, return_tensors="pt")
    translated_tokens = model.generate(**inputs, forced_bos_token_id=tokenizer.convert_tokens_to_ids(lang_code))
    return tokenizer.batch_decode(translated_tokens, skip_special_tokens=True)[0]

# Function to translate only specific fields and store
def translate_scholarships(data, lang_code, lang_name):
    translated_data = []

    for item in data:
        translated_item = item.copy()
        translated_item["scholarshipName"] = indianTrans(item["scholarshipName"], lang_code)
        translated_item["description"] = indianTrans(item["description"], lang_code)
        translated_data.append(translated_item)

    db["TranslatedScholarships"].insert_one({
        "language": lang_name,
        "language_code": lang_code,
        "translated_scholarships": translated_data,
        "created_on": datetime.now()
    })
    print(f"Stored translated scholarships for {lang_name}")

# Your input data
input_scholarships = [    {      _id: 1,      scholarshipName: 'CSIR Research Fellowship',      description: 'The Council of Scientific and Industrial Research (CSIR) offers fellowships to support research in fields of science and technology.',      deadline: 'Typically in May/June annually.',      scholarshipURL: 'https://csirhrdg.res.in/',    },    {      _id: 2,      imageUrl: 'https://via.placeholder.com/150',      scholarshipName: 'ICMR Junior Research Fellowship',      description: 'The Indian Council of Medical Research (ICMR) provides fellowships for biomedical sciences to support junior researchers.',      deadline: 'Usually in July annually.',      scholarshipURL: 'https://www.icmr.nic.in/content/junior-research-fellowships-jrf',    },    {      _id: 3,      imageUrl: 'https://via.placeholder.com/150',      scholarshipName: 'UGC NET Junior Research Fellowship',      description: 'The University Grants Commission (UGC) offers Junior Research Fellowships for qualifying candidates through the NET exam.',      deadline: 'Typically in March/April and September/October annually.',      scholarshipURL: 'https://www.ugcnetonline.in/',    },    {      _id: 4,      imageUrl: 'https://via.placeholder.com/150',      scholarshipName: 'INSPIRE Fellowship',      description: 'The INSPIRE Fellowship is offered by the Department of Science and Technology (DST) to support students pursuing doctoral research in basic and applied sciences.',      deadline: 'Varies; typically in September annually.',      scholarshipURL: 'https://online-inspire.gov.in/',    },    {      _id: 5,      imageUrl: 'https://via.placeholder.com/150',      scholarshipName: 'DST Women Scientists Scheme',      description: 'This scheme by the Department of Science and Technology (DST) supports women scientists for research and development projects.',      deadline: 'Varies; check the DST website for updates.',      scholarshipURL: 'https://dst.gov.in/scientific-programmes/scientific-engineering-research/women-scientists-programmes',    },    {      _id: 6,      imageUrl: 'https://via.placeholder.com/150',      scholarshipName: 'Prime Minister’s Research Fellowship (PMRF)',      description: 'PMRF aims to attract the best talent into research by offering attractive fellowships to pursue Ph.D. at premier institutions in India.',      deadline: 'Typically in May and December annually.',      scholarshipURL: 'https://www.pmrf.in/',    },    {      _id: 7,      imageUrl: 'https://via.placeholder.com/150',      scholarshipName: 'Wellcome Trust/DBT India Alliance Fellowship',      description: 'This fellowship supports biomedical research and is available to early-career, intermediate, and senior researchers.',      deadline: 'Varies; check the India Alliance website.',      scholarshipURL: 'https://www.indiaalliance.org/',    },    {      _id: 8,      imageUrl: 'https://via.placeholder.com/150',      scholarshipName: 'Fulbright-Nehru Doctoral Research Fellowships',      description: 'These fellowships are for Indian scholars who are registered for a Ph.D. at an Indian institution to conduct research in the U.S.',      deadline: 'Typically in July annually.',      scholarshipURL: 'https://www.usief.org.in/Fulbright-Nehru-Doctoral-Research-Fellowships.aspx',    },    {      _id: 9,      imageUrl: 'https://via.placeholder.com/150',      scholarshipName: 'Ramanujan Fellowship',      description: 'The Ramanujan Fellowship is meant for brilliant Indian scientists and engineers from the world to take up scientific research positions.',      deadline: 'Applications are accepted throughout the year.',      scholarshipURL: 'https://www.serb.gov.in/schemes/ramanujan-fellowships',    },    {      _id: 10,      imageUrl: 'https://via.placeholder.com/150',      scholarshipName: 'Alexander von Humboldt Research Fellowship',      description: 'This fellowship enables highly qualified scientists and scholars from abroad to conduct research in Germany.',      deadline: 'Applications are accepted throughout the year.',      scholarshipURL: 'https://www.humboldt-foundation.de/',    },]

# Loop through languages
for code, name in zip(language_codes, language_names):
    translate_scholarships(input_scholarships, code, name)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/564 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/4.85M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.3M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/3.55k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/846 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/2.46G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.46G [00:00<?, ?B/s]
# ...

# %%
# !pip install flask flask-ngrok --ignore-installed blinker
# Out:
# ...
#   Using cached flask-3.1.1-py3-none-any.whl.metadata (3.0 kB)
# ...
#   Using cached flask_ngrok-0.0.25-py3-none-any.whl.metadata (1.8 kB)
# ...
#   Using cached blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# ...
#   Using cached click-8.2.1-py3-none-any.whl.metadata (2.5 kB)
# ...
#   Using cached itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# ...
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# ...
#   Using cached MarkupSafe-3.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# ...
#   Using cached werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# ...
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# ...
#   Using cached charset_normalizer-3.4.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (35 kB)
# ...
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached urllib3-2.4.0-py3-none-any.whl.metadata (6.5 kB)
# ...
#   Using cached certifi-2025.4.26-py3-none-any.whl.metadata (2.5 kB)
# ...

# %%
# !wget -q -nc https://bin.equinox.io/c/bNyj1mQVY4c/ngrok-stable-linux-amd64.zip
# !unzip -o ngrok-stable-linux-amd64.zip
# Out:
# Archive:  ngrok-stable-linux-amd64.zip
#   inflating: ngrok

# %%
# !ngrok config add-authtoken ngrok config add-authtoken 2xhqagmNQzfoOJrwnWIvcy4oggJ_3pxKkEVBfZuK7uPx7BBg5
# Out:
# /bin/bash: line 1: ngrok: command not found

# %%
from flask import Flask, request, render_template_string, redirect
from pymongo import MongoClient
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
from datetime import datetime
from flask_ngrok import run_with_ngrok
import threading

# Setup Flask app
app = Flask(__name__)

# MongoDB
client = MongoClient("mongodb+srv://manisalian:PqXNq8KvMLpXplxP@crud.jeyup.mongodb.net/NEWS?retryWrites=true&w=majority&appName=NEWS")
db = client["NEWS"]

# Load translation model
tokenizer = AutoTokenizer.from_pretrained("facebook/nllb-200-distilled-600M")
model = AutoModelForSeq2SeqLM.from_pretrained("facebook/nllb-200-distilled-600M")

language_codes = ["hin_Deva", "guj_Gujr"]
language_names = ["Hindi", "Gujarati"]

def translate(text, lang_code):
    inputs = tokenizer(text, return_tensors="pt")
    tokens = model.generate(**inputs, forced_bos_token_id=tokenizer.convert_tokens_to_ids(lang_code))
    return tokenizer.batch_decode(tokens, skip_special_tokens=True)[0]

form_html = """
<!doctype html>
<title>Add News</title>
<h2>Add English News</h2>
<form method="POST">
  Image URL: <input name="img_url"><br><br>
  Title: <input name="title"><br><br>
  Author: <input name="author"><br><br>
  Short Description:<br><textarea name="short_desc"></textarea><br><br>
  Full Description:<br><textarea name="desc"></textarea><br><br>
  <input type="submit" value="Submit and Translate">
</form>
"""

@app.route('/', methods=['GET', 'POST'])
def index():
    if request.method == 'POST':
        data = {
            "post_id": db["English"].count_documents({}) + 1,
            "img_url": request.form["img_url"],
            "title": request.form["title"],
            "author": request.form["author"],
            "short_desc": request.form["short_desc"],
            "desc": request.form["desc"],
            "created_on": datetime.now()
        }
        db["English"].insert_one(data)

        for code, name in zip(language_codes, language_names):
            translated = {
                "post_id": data["post_id"],
                "img_url": data["img_url"],
                "title": translate(data["title"], code),
                "author": translate(data["author"], code),
                "short_desc": translate(data["short_desc"], code),
                "desc": translate(data["desc"], code),
                "created_on": data["created_on"]
            }
            db[name].insert_one(translated)

        return "<h3>News submitted and translated!</h3>"

    return render_template_string(form_html)
def run_app():
    app.run(port=5000)

thread = threading.Thread(target=run_app)
thread.start()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off

# %%
from flask import Flask, request, render_template_string, redirect
from pymongo import MongoClient
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
from datetime import datetime

# Setup Flask app
app = Flask(__name__)

# MongoDB
client = MongoClient(os.environ["MONGO_URI"])
db = client["NEWS"]

# Load translation model
tokenizer = AutoTokenizer.from_pretrained("facebook/nllb-200-distilled-600M")
model = AutoModelForSeq2SeqLM.from_pretrained("facebook/nllb-200-distilled-600M")

language_codes = ["hin_Deva", "guj_Gujr"]
language_names = ["Hindi", "Gujarati"]

def translate(text, lang_code):
    inputs = tokenizer(text, return_tensors="pt")
    tokens = model.generate(**inputs, forced_bos_token_id=tokenizer.convert_tokens_to_ids(lang_code))
    return tokenizer.batch_decode(tokens, skip_special_tokens=True)[0]

form_html = """
<!doctype html>
<title>Add News</title>
<h2>Add English News</h2>
<form method="POST">
  Image URL: <input name="img_url"><br><br>
  Title: <input name="title"><br><br>
  Author: <input name="author"><br><br>
  Short Description:<br><textarea name="short_desc"></textarea><br><br>
  Full Description:<br><textarea name="desc"></textarea><br><br>
  <input type="submit" value="Submit and Translate">
</form>
"""

@app.route('/', methods=['GET', 'POST'])
def index():
    if request.method == 'POST':
        data = {
            "post_id": db["English"].count_documents({}) + 1,
            "img_url": request.form["img_url"],
            "title": request.form["title"],
            "author": request.form["author"],
            "short_desc": request.form["short_desc"],
            "desc": request.form["desc"],
            "created_on": datetime.now()
        }
        db["English"].insert_one(data)

        for code, name in zip(language_codes, language_names):
            translated = {
                "post_id": data["post_id"],
                "img_url": data["img_url"],
                "title": translate(data["title"], code),
                "author": translate(data["author"], code),
                "short_desc": translate(data["short_desc"], code),
                "desc": translate(data["desc"], code),
                "created_on": data["created_on"]
            }
            db[name].insert_one(translated)

        return "<h3>News submitted and translated!</h3>"

    return render_template_string(form_html)

# %%
# !./ngrok http 5000
